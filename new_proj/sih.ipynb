# %%
import pandas as pd

# %%
df = pd.read_csv("mplads_completed_works_2026-09-13.csv")

# %%
df.head()
# Out:
#    Work ID                                   Work Description       Category  \
# 0   134703  Upgradation of Road from Madhavaram Village to...  Normal/Others
# 1   135593  Construction of CC Road from Amudala Village t...  Normal/Others
# 2   135595  Construction of CC road from Amudala Village t...  Normal/Others
# 3   135639  Construction of Under Ground Drainage at Thala...  Normal/Others
# 4   135640  Construction of Under Ground Draiange at Thala...  Normal/Others
#
#                   MP Name Constituency           State      House  \
# 0  DAGGUMALLA PRASADA RAO     CHITTOOR  Andhra Pradesh  Lok Sabha
# 1  DAGGUMALLA PRASADA RAO     CHITTOOR  Andhra Pradesh  Lok Sabha
# 2  DAGGUMALLA PRASADA RAO     CHITTOOR  Andhra Pradesh  Lok Sabha
# 3  DAGGUMALLA PRASADA RAO     CHITTOOR  Andhra Pradesh  Lok Sabha
# 4  DAGGUMALLA PRASADA RAO     CHITTOOR  Andhra Pradesh  Lok Sabha
#
#    Final Amount (₹)            Completed Date  Has Images  Average Rating  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44028 entries, 0 to 44027
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Work ID           44028 non-null  int64
#  1   Work Description  43943 non-null  object
#  2   Category          44023 non-null  object
#  3   MP Name           44028 non-null  object
#  4   Constituency      44028 non-null  object
#  5   State             44028 non-null  object
#  6   House             44028 non-null  object
#  7   Final Amount (₹)  44028 non-null  float64
#  8   Completed Date    44028 non-null  object
#  9   Has Images        44028 non-null  bool
#  10  Average Rating    4 non-null      float64
#  11  IDA               44028 non-null  object
# dtypes: bool(1), float64(2), int64(1), object(8)
# memory usage: 3.7+ MB
